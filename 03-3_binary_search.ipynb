# %% [markdown]
# # 이진 검색
# - 원소가 정렬된 배열에서 효율적으로 검색할 수 있는 알고리즘
# - 선형 검색보다 매우 빠르
# 게 검색 가능
#
#
# ### 필요한 변수
#  - pl: 검색범위의맨앞(=0)
#  - pr: 검색범위의맨끝(=n-1)
#  - pc: 중앙원소인덱스(=(pl+pr)//2)
#
#
# ### 종료조건
# - 중앙원소가키값과일치하는경우
# ==>성공
# - 검색범위가더이상없는경우**(pl > pr)**
# ==>실패

# %%
from typing import Any,Sequence

def bin_search(a:Sequence,key:Any) -> int:
    pl = 0
    pr = len(a)-1

    while True:
        pc = (pl+pr)//2
        if a[pc] == key:
            return pc
        elif a[pc] < key:
            pl = pc+1
        else:
            pr = pc-1
        if pl > pr:# pl이 pr 추월
            break
    return -1 # 검색 실패

if __name__ == '__main__':
    num = int(input('원소 수를 입력하세요.:'))
    x = [None]*num

    print('배열 데이터를 오름차순으로 입력하세요.')

    x[0] = int(input('x[0]: '))

    for i in range(1,num):
        while True:
            x[i] = int(input(f'x[{i}]: '))
            if x[i] >= x[i-1]:
                break

    ky = int(input('검색할 값을 입력하세요.: '))

    idx = bin_search(x,ky)

    if idx == -1:
        print('검색값을 갖는 원소가 존재하지 않습니다.')
    else:
        print(f'검색값은 x[{idx}]에 있습니다.')
# Out:
# 원소 수를 입력하세요.:7
# 배열 데이터를 오름차순으로 입력하세요.
# x[0]: 1
# x[1]: 2
# x[2]: 3
# x[3]: 5
# x[4]: 7
# x[5]: 8
# x[6]: 9
# 검색할 값을 입력하세요.: 5
# 검색값은 x[3]에 있습니다.

# %% [markdown]
# ### index() 함수로검색하기==> 평소엔 이거 사용하면 됨
# obj.index(x, i, j)
#
# ==>원소가없으면 ValueError예외를 발생
#
# ==>원소가있으면 그가운데 가장작은 인덱스를 반환

# %%
# 이진 검색 실행 과정 출력 (시험 x)

from typing import Any,Sequence

def bin_search(a:Sequence,key:Any) -> int:
    pl = 0
    pr = len(a) -1

    print('   |', end='')
    for i in range(len(a)):
        print(f'{i:4}',end='')
    print()
    print('---+' + (4*len(a)+2)*'-')

    while True:
        pc = (pl+pr)//2

        print('   |',end='')
        if pl != pc:
            print((pl*4+1)*' '+'<-'+((pc-pl)*4)*' '+'+',end='')
        else:
            print((pc*4+1)*' '+'<+',end='')
        if pc != pr:
            print(((pr-pc)*4-2)*' '+'->',end='')
        else:
            print('->')
        print(f'{pc:3}|', end='')
        for i in range(len(a)):
            print(f'{a[i]:4}',end='')
        print('\n   |')

# %% [markdown]
# ## 복잡도
# - 알고리즘의 성능을 객관적으로 평가하는 기준
# - **시간복잡도** : 필요한 시간을 평가
#
#     입력데이터크기(n)에대해수행되는횟수로표기(직접 수행 시간 재지 않음)
#
# - **공간 복잡도** : 메모리와 파일 공간이 얼마나 필요한지 평가
#
#
# ![image.png](data:image/png;base64,...)
#
# #### 점근적 상한 (big-O)
# - 최고차항의 차수가 𝑓(𝑛)과 **일치하거나 작은** 함수의 집합
#
#     (𝑓(𝑛)을 넘지않는 모든 함수의 집합)
#
#     eg.  5𝑛^2+4𝑛=Ο(n^2)
#
#
#     ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 이진 검색의 시간 복잡도
# 종료 조건 판단의 평균 실행 획수 $log_2n = O(logn)$
#
# O(1) + O(1) + O(logn) + O(logn1) + .. + O(1) = O(logn)
