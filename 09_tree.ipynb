# %% [markdown]
# <a href="https://colab.research.google.com/github/sujeengim/ALGORITHM/blob/main/09_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 9-1 트리
# - 데이터 사이의 계층 관계를 표현하는 자료구조 (위계, hierarchy)
# - 노드node와 가지edge
# ![image.png](data:image/png;base64,...)
#
# - 용어
#     - 루트root :
#     - 리프leaf : 자식 없는 노드
#     - 비단말노드(내부노드)non-terminal node(internal node) : 리프를 제외한 모든 노드
#     - 부모 : 루트는 부모 노드가 없다
#     - 자식 : 노드의 가지 아래쪽으로 연결된 노드
#     - 차수degree : 각 노드의 자식 수 (리프의 차수는 0)
#     - n진 트리 : 모든 노드의 차수가 n 이하인 트리 (이미지는 3진트리)
#     - 형제sibling  : 부모 같은 노드
#     - 조상ancestor : 위쪽으로 가지를 따라가면 만나는
# 모든 노드
#     - 자손descendant : 아래쪽으로 가지를 따라가면 만나는
# 모든 노드
#     - 레벨level : 루트의 레벨은 0 <br/>
#     가지가 하나씩 아래로 뻗어 나갈 때마다 레벨이 1씩 증가 <br/>
#     이미지에서 레벨은 3임
#     - 높이height : 레벨의 최댓값
#     - 서브트리 : 이미지에서 X를 루트로 하는 서브트리
#     - 널트리  : 빈트리
#     - 순서 트리ordered tree : 형제 노드의 순서 관계가 있는 트리(ex. 완전 이진 트리)
#     - 무순서 트리unordered tree : 형제 노드의 순서 관계를 구별하지 않는 트리
#
#
# ### 순서트리 검색
# - 너비 우선 검색
# - 깊이 우선 검색
# - 추가) 완전 이진 트리는 왼쪽에서부터 채워져야 하므로,
# 자식 노드의 위치(왼쪽/오른쪽) 이 매우 중요

# %% [markdown]
# ### 너비 우선 검색 BFS
# - 루트부터 시작하여  한층씩 가로로 내려가며 검색함
# - 가로 검색

# %% [markdown]
# ### 깊이 우선 검색 DFS
# - 세로 검색
# - 루트에서 시작하여 자식노드가 있다면 리프에 도달할때까지 세로로 내려가며 검색함
# - 루트를 언제 확인할건지에 따라 검색 방법 달라짐(처음, 중간, 마지막)<br/>
# 아래 이미지는 전위순위의 경우 A를 총 3번 방문
#
# ![image.png](data:image/png;base64,...)
#
#
#
# - 전위순회 preorder :
#     - A -> 왼쪽 자식 -> 오른쪽 자식
#     - <u>A</u> →B →D →H →E →I →J →C →F →K →L →G
# - 중앙순회 inorder :
#     - 왼쪽 자식 -> A -> 오른쪽 자식
#     - H →D →B →I →E →J →<u>A</u> →K →F →L →C →G
# - 후위순회 postorder :
#     - 왼쪽 자식 -> 오른쪽 자식 -> A
#     - H →D →I →J →E →B →K →L →F →G →C → <u>A</u>
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 9-2 이진 트리

# %% [markdown]
# - 왼쪽 자식과 오른쪽 자식만 갖는 트리 (둘다 또는 둘중하나가 없어도 됨)

# %% [markdown]
# ### 완전 이진 트리
# - 루트부터 아래쪽 레벨로 노드가 가득 차 있고,
# 같은 레벨 안에서 왼쪽부터 오른쪽으로 노드가 <br/>
# 채워진 이진 트리
# - 레벨이 커질 수록 노드 수가 2배가 됨
# - 높이 k의 최대 노드수 : 2^(k+1) − 1개
# - n개의 노드 저장할 트리의 높이는 row(log2 n)

# %% [markdown]
# ### 균형검색 트리
# - 이진트리의 불균형 위함

# %% [markdown]
# ### 이진 검색 트리
# - 조건
#     - 왼쪽 서브트리는 부모노드(key)보다 작은 값
#     - 오른쪽 서브트리는 부모노드(key)보다 큰 값
#     - 키가 같으면 복수 존재 x
# - 중위순회 하면 <u>오름차순 정렬</u>됨

# %% [markdown]
# ### 이진 검색 트리 구현
# - key: 키(임의의 자료형)
# - value: 값(임의의 자료형)
# - left: 왼쪽 자식 노드에 대한 참조(왼쪽 포인터)
# - right: 오른쪽 자식 노드에 대한 참조(오른쪽 포인터)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 검색 과정
# - 주목과 검색하는 키 비교
# - 먼저 루트 주목
# - 루트보다 작으면 왼쪽, 크면 오른쪽으로 가며 검색하는 키를 찾기
#     - == : 발견
#     - < : 주목을 왼쪽으로
#     - > : 주목을 오른쪽으로
#
# ### 삽입
# - 주목과 삽입할 키 비교
# - 먼저 루트 주목
# - 이미 같은 값이 존재하면 삽입 실패 (이진검색트리에서 키 같을 수 없음)
#     - == : 실패
#     - < : 주목을 왼쪽으로
#     - > : 주목을 오른쪽으로
#
# ### 삭제 (약간 복잡)ㅈ
# - 삭제할 노드가 리프인 경우
#     - 처음엔 검색하여 삭제 키가 존재하는지 확인
#     - 주목과 삭제할 키가 같다면(발견했다면)<br/>
#     한 노드의 부모노드의 자식을 null로 바꾸기
# - 삭제할 노드의 자식이 1개인 경우
#     - 노드만 제거하여 하나씩 위로 당겨진다.
# - 삭제할 노드의 자식이 2개인 경우
#     - 해당 서브트리에서 가장 큰 값을 삭제 위치로 가져온다.

# %%
# %%writefile bst2.py
from __future__ import annotations
from typing import Any, Type

class Node:
    def __init__(self, key:Any, value:Any, left:Node=None, right:Node=None):
        self.key = key
        self.value = value
        self.left = left
        self.right = right

class BinarySearchTree:
    def __init__(self):
        self.root = None

    def search(self, key:Any) -> Any:
        p = self.root
        while True:
            if p is None:
                return None
            if key == p.key:
                return p.value
            elif key < p.key:
                p = p.left
            else:
                p = p.right

    def add(self, key:Any, value:Any) -> bool:
        def add_node(node:Node, key:Any, value:Any) -> None:
            if key == node.key:
                return False
            elif key < node.key:
                if node.left is None:
                    node.left = Node(key, value, None, None)
                else:
                    add_node(node.left, key, value)
            else:
                if node.right is None:
                    node.right = Node(key, value, None, None)
                else:
                    add_node(node.right, key, value)
            return True
        if self.root is None:
            self.root = Node(key, value, None, None)
            return True
        else:
            return add_node(self.root, key, value)

    def remove(self, key:Any) -> bool:
        p = self.root
        parent = None
        is_left_child = True
        while True:
            if p is None:
                return False

            if key == p.key:
                break
            else:
                parent = p
                if key < p.key:
                    is_left_chile = True
                    p = p.left
                else:
                    is_left_child = False
                    p = p.right
        if p.left is None:
            if p is self.root:
                self.root = p.right
            elif is_left_child:
                parent.left = p.right
            else:
                parent.right = p.right

        elif p.right is None:
            if p is self.root:
                self.root = p.left
            elif is_left_child:
                parent.left = p.left
            else:
                parent.right = p.left
        else:
            parent = p
            left = p.left
            is_left_child = True
            while left.right is not None:
                parent = left
                left = left.right
                is_left_child = False
            p.key = left.key
            p.value = left.value
            if is_left_child:
                parent.left = left.left
            else:
                parent.right = left.left
        return True

    def dump(self) -> None:
        def print_subtree(node:Node):
            if node is not None:
                print_subtree(node.left)
                print(f'{node.key} {node.value}')
                print_subtree(node.right)

        print_subtree(self.root)
    def min_key(self) -> Any:
        if self.root is None:
            return None
        p = self.root
        while p.left is not None:
            p = p.left
        return p.key
    def max_key(self) -> Any:
        if self.root is None:
            return None
        p = self.root
        while p.right is not None:
            p = p.right
        return p.key
# Out:
# Writing bst2.py

# %%
from enum import Enum
from bst2 import BinarySearchTree

Menu = Enum('Menu', ['삽입', '삭제', '검색', '덤프', '키의범위', '종료'])

def select_Menu() -> None:
    s = [f'({m.value}){m.name}' for m in Menu]
    while True:
        print(*s, sep=' ', end='')
        n = int(input(': '))
        if 1 <= n <= len(Menu):
            return Menu(n)

tree = BinarySearchTree()

while True:
    menu = select_Menu()

    if menu == Menu.삽입:
        key = int(input('삽입할 키를 입력하세요.: '))
        val = input('삽입할 값을 입력하세요.: ')
        if not tree.add(key, val):
            print('삽입에 실패했습니다!')

    elif menu == Menu.삭제:
        key = int(input('삭제할 키를 입력하세요.: '))
        tree.remove(key)

    elif menu == Menu.검색:
        key = int(input('검색할 값을 입력하세요.: '))
        t = tree.search(key)
        if t is not None:
            print(f'이 키를 갖는 값은 {t}입니다. ')
        else:
            print('해당하는 데이터가 없습니다. ')
    elif menu == Menu.덤프:
        tree.dump()

    elif menu == Menu.키의범위:
        print(f'키의 최솟값은 {tree.min_key()}입니다.')
        print(f'키의 최댓값은 {tree.max_key()}입니다.')
    else:
        break
# Out:
# (1)삽입 (2)삭제 (3)검색 (4)덤프 (5)키의범위 (6)종료: 1
# 삽입할 키를 입력하세요.: 2
# 삽입할 값을 입력하세요.: 32
# (1)삽입 (2)삭제 (3)검색 (4)덤프 (5)키의범위 (6)종료: 4
# 2 32
# (1)삽입 (2)삭제 (3)검색 (4)덤프 (5)키의범위 (6)종료: 55
# (1)삽입 (2)삭제 (3)검색 (4)덤프 (5)키의범위 (6)종료: 4
# 2 32
# (1)삽입 (2)삭제 (3)검색 (4)덤프 (5)키의범위 (6)종료: 3
# 검색할 값을 입력하세요.: 2
# 이 키를 갖는 값은 32입니다.
# (1)삽입 (2)삭제 (3)검색 (4)덤프 (5)키의범위 (6)종료: 6
